# %% [markdown]
# # Advent of Code
# ## Day 3: Camp Cleanup
#
# ### Part 1
#
# Space needs to be cleared before the last supplies can be unloaded from the ships, and so several Elves have been assigned the job of cleaning up sections of the camp. Every section has a unique ID number, and each Elf is assigned a range of section IDs.
#
# However, as some of the Elves compare their section assignments with each other, they've noticed that many of the assignments overlap. To try to quickly find overlaps and reduce duplicated effort, the Elves pair up and make a big list of the section assignments for each pair (your puzzle input).
#
# For example, consider the following list of section assignment pairs:
#
# `
# 2-4,6-8
# 2-3,4-5
# 5-7,7-9
# 2-8,3-7
# 6-6,4-6
# 2-6,4-8
# `
#
# For the first few pairs, this list means:
#
# - Within the first pair of Elves, the first Elf was assigned sections 2-4 (sections 2, 3, and 4), while the second Elf was assigned sections 6-8 (sections 6, 7, 8).
# - The Elves in the second pair were each assigned two sections.
# - The Elves in the third pair were each assigned three sections: one got sections 5, 6, and 7, while the other also got 7, plus 8 and 9.
#
# This example list uses single-digit section IDs to make it easier to draw; your actual list might contain larger numbers. Visually, these pairs of section assignments look like this:
#
# `
# .234.....  2-4
#
# .....678.  6-8
#
#
# .23......  2-3
#
# ...45....  4-5
#
# ....567..  5-7
#
# ......789  7-9
#
# .2345678.  2-8
#
# ..34567..  3-7
#
# .....6...  6-6
#
# ...456...  4-6
#
# .23456...  2-6
#
# ...45678.  4-8
# `
#
# Some of the pairs have noticed that one of their assignments fully contains the other. For example, 2-8 fully contains 3-7, and 6-6 is fully contained by 4-6. In pairs where one assignment fully contains the other, one Elf in the pair would be exclusively cleaning sections their partner will already be cleaning, so these seem like the most in need of reconsideration. In this example, there are 2 such pairs.
#
# In how many assignment pairs does one range fully contain the other?

# %%
# Test

# Set up the data
test_input = ['2-4,6-8', '2-3,4-5', '5-7,7-9', '2-8,3-7', '6-6,4-6', '2-6,4-8']

full_contained_count = 0

for i in range(len(test_input)):
    print('Elf pair', i+1)
    sections = test_input[i]
    print('Overall sections:', sections)
    
    section_split = sections.find(',')
    
    # What section did each elf have to cover?
    first_elf = sections[:section_split]
    second_elf = sections[section_split+1:]
    
    print('First elf covers:', first_elf)
    print('Second elf covers:', second_elf)
    
    # What are the ranges of the sections that the elves need to cover?
    first_elf_split = first_elf.find('-')
    
    first_elf_lower = int(first_elf[:first_elf_split])
    first_elf_upper = int(first_elf[first_elf_split+1:])
    print('First elf covers section', first_elf_lower, 'to section', first_elf_upper)
    
    second_elf_split = second_elf.find('-')
    
    second_elf_lower = int(second_elf[:second_elf_split])
    second_elf_upper = int(second_elf[second_elf_split+1:])
    print('Second elf covers section', second_elf_lower, 'to section', second_elf_upper)
    
    # How many fully contained sections are there?
    if ( ( (second_elf_lower >= first_elf_lower) and (first_elf_upper >= second_elf_upper) ) or
         ( ( first_elf_lower >= second_elf_lower) and (second_elf_upper >= first_elf_upper) ) ):
        full_contained_count += 1
    
    print('Fully contained sections so far:', full_contained_count)
    print('--------------')
    
print('Total number of fully contained sections:', full_contained_count)
# Out:
# Elf pair 1
# Overall sections: 2-4,6-8
# First elf covers: 2-4
# Second elf covers: 6-8
# First elf covers section 2 to section 4
# Second elf covers section 6 to section 8
# Fully contained sections so far: 0
# --------------
# Elf pair 2
# Overall sections: 2-3,4-5
# First elf covers: 2-3
# Second elf covers: 4-5
# First elf covers section 2 to section 3
# Second elf covers section 4 to section 5
# Fully contained sections so far: 0
# --------------
# Elf pair 3
# Overall sections: 5-7,7-9
# First elf covers: 5-7
# Second elf covers: 7-9
# First elf covers section 5 to section 7
# Second elf covers section 7 to section 9
# Fully contained sections so far: 0
# --------------
# Elf pair 4
# Overall sections: 2-8,3-7
# First elf covers: 2-8
# Second elf covers: 3-7
# First elf covers section 2 to section 8
# Second elf covers section 3 to section 7
# Fully contained sections so far: 1
# --------------
# Elf pair 5
# Overall sections: 6-6,4-6
# First elf covers: 6-6
# ...

# %%
# Read in the data
with open('Day 4 input.txt', 'r') as f:
    my_input = []
    for item in f:
        my_input.append(item[:-1])

print(len(my_input))
# Out:
# 1000

# %%
full_contained_count = 0

for i in range(len(my_input)):
    sections = my_input[i]
    
    section_split = sections.find(',')
    
    # What section did each elf have to cover?
    first_elf = sections[:section_split]
    second_elf = sections[section_split+1:]
    
    # What are the ranges of the sections that the elves need to cover?
    first_elf_split = first_elf.find('-')
    
    first_elf_lower = int(first_elf[:first_elf_split])
    first_elf_upper = int(first_elf[first_elf_split+1:])
        
    second_elf_split = second_elf.find('-')
    
    second_elf_lower = int(second_elf[:second_elf_split])
    second_elf_upper = int(second_elf[second_elf_split+1:])
        
    # How many fully contained sections are there?
    if ( ( (second_elf_lower >= first_elf_lower) and (first_elf_upper >= second_elf_upper) ) or
         ( ( first_elf_lower >= second_elf_lower) and (second_elf_upper >= first_elf_upper) ) ):
        full_contained_count += 1
    
print('Total number of fully contained sections:', full_contained_count)
# Out:
# Total number of fully contained sections: 483

# %% [markdown]
# ### Part 2
#
# It seems like there is still quite a bit of duplicate work planned. Instead, the Elves would like to know the number of pairs that overlap at all.
#
# In the above example, the first two pairs (`2-4,6-8` and `2-3,4-5`) don't overlap, while the remaining four pairs (`5-7,7-9`, `2-8,3-7`, `6-6,4-6`, and `2-6,4-8`) do overlap:
#
# - 5-7,7-9 overlaps in a single section, 7.
# - 2-8,3-7 overlaps all of the sections 3 through 7.
# - 6-6,4-6 overlaps in a single section, 6.
# - 2-6,4-8 overlaps in sections 4, 5, and 6.
#
# So, in this example, the number of overlapping assignment pairs is 4.
#
# In how many assignment pairs do the ranges overlap?

# %%
# Test

# Set up the data
test_input = ['2-4,6-8', '2-3,4-5', '5-7,7-9', '2-8,3-7', '6-6,4-6', '2-6,4-8']

partly_contained_count = 0

for i in range(len(test_input)):
    print('Elf pair', i+1)
    sections = test_input[i]
    print('Overall sections:', sections)
    
    section_split = sections.find(',')
    
    # What section did each elf have to cover?
    first_elf = sections[:section_split]
    second_elf = sections[section_split+1:]
    
    print('First elf covers:', first_elf)
    print('Second elf covers:', second_elf)
    
    # What are the ranges of the sections that the elves need to cover?
    first_elf_split = first_elf.find('-')
    
    first_elf_lower = int(first_elf[:first_elf_split])
    first_elf_upper = int(first_elf[first_elf_split+1:])
    print('First elf covers section', first_elf_lower, 'to section', first_elf_upper)
    
    second_elf_split = second_elf.find('-')
    
    second_elf_lower = int(second_elf[:second_elf_split])
    second_elf_upper = int(second_elf[second_elf_split+1:])
    print('Second elf covers section', second_elf_lower, 'to section', second_elf_upper)
    
    # How many fully contained sections are there?
    if ( (first_elf_lower >= second_elf_lower and first_elf_lower <= second_elf_upper) or
         (first_elf_upper >= second_elf_lower and first_elf_upper <= second_elf_upper) or
         (second_elf_lower >= first_elf_lower and second_elf_lower <= first_elf_upper) or
         (second_elf_upper >= first_elf_lower and second_elf_upper <= first_elf_upper) ):
        partly_contained_count += 1
    
    print('Fully contained sections so far:', partly_contained_count)
    print('--------------')
    
print('Total number of fully contained sections:', partly_contained_count)
# Out:
# Elf pair 1
# Overall sections: 2-4,6-8
# First elf covers: 2-4
# Second elf covers: 6-8
# First elf covers section 2 to section 4
# Second elf covers section 6 to section 8
# Fully contained sections so far: 0
# --------------
# Elf pair 2
# Overall sections: 2-3,4-5
# First elf covers: 2-3
# Second elf covers: 4-5
# First elf covers section 2 to section 3
# Second elf covers section 4 to section 5
# Fully contained sections so far: 0
# --------------
# Elf pair 3
# Overall sections: 5-7,7-9
# First elf covers: 5-7
# Second elf covers: 7-9
# First elf covers section 5 to section 7
# Second elf covers section 7 to section 9
# Fully contained sections so far: 1
# --------------
# Elf pair 4
# Overall sections: 2-8,3-7
# First elf covers: 2-8
# Second elf covers: 3-7
# First elf covers section 2 to section 8
# Second elf covers section 3 to section 7
# Fully contained sections so far: 2
# --------------
# Elf pair 5
# Overall sections: 6-6,4-6
# First elf covers: 6-6
# ...

# %%
partly_contained_count = 0

for i in range(len(my_input)):
    sections = my_input[i]
    
    section_split = sections.find(',')
    
    # What section did each elf have to cover?
    first_elf = sections[:section_split]
    second_elf = sections[section_split+1:]
        
    # What are the ranges of the sections that the elves need to cover?
    first_elf_split = first_elf.find('-')
    
    first_elf_lower = int(first_elf[:first_elf_split])
    first_elf_upper = int(first_elf[first_elf_split+1:])
    
    second_elf_split = second_elf.find('-')
    
    second_elf_lower = int(second_elf[:second_elf_split])
    second_elf_upper = int(second_elf[second_elf_split+1:])
    
    # How many fully contained sections are there?
    if ( (first_elf_lower >= second_elf_lower and first_elf_lower <= second_elf_upper) or
         (first_elf_upper >= second_elf_lower and first_elf_upper <= second_elf_upper) or
         (second_elf_lower >= first_elf_lower and second_elf_lower <= first_elf_upper) or
         (second_elf_upper >= first_elf_lower and second_elf_upper <= first_elf_upper) ):
        partly_contained_count += 1
    
print('Total number of fully contained sections:', partly_contained_count)
# Out:
# Total number of fully contained sections: 874

# %% [markdown]
# ### Run Time

# %%
# %%timeit
full_contained_count = 0

for i in range(len(my_input)):
    sections = my_input[i]
    
    section_split = sections.find(',')
    
    # What section did each elf have to cover?
    first_elf = sections[:section_split]
    second_elf = sections[section_split+1:]
    
    # What are the ranges of the sections that the elves need to cover?
    first_elf_split = first_elf.find('-')
    
    first_elf_lower = int(first_elf[:first_elf_split])
    first_elf_upper = int(first_elf[first_elf_split+1:])
        
    second_elf_split = second_elf.find('-')
    
    second_elf_lower = int(second_elf[:second_elf_split])
    second_elf_upper = int(second_elf[second_elf_split+1:])
        
    # How many fully contained sections are there?
    if ( ( (second_elf_lower >= first_elf_lower) and (first_elf_upper >= second_elf_upper) ) or
         ( ( first_elf_lower >= second_elf_lower) and (second_elf_upper >= first_elf_upper) ) ):
        full_contained_count += 1
    
# print('Total number of fully contained sections:', full_contained_count)
# Out:
# 3.14 ms ± 127 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
partly_contained_count = 0

for i in range(len(my_input)):
    sections = my_input[i]
    
    section_split = sections.find(',')
    
    # What section did each elf have to cover?
    first_elf = sections[:section_split]
    second_elf = sections[section_split+1:]
        
    # What are the ranges of the sections that the elves need to cover?
    first_elf_split = first_elf.find('-')
    
    first_elf_lower = int(first_elf[:first_elf_split])
    first_elf_upper = int(first_elf[first_elf_split+1:])
    
    second_elf_split = second_elf.find('-')
    
    second_elf_lower = int(second_elf[:second_elf_split])
    second_elf_upper = int(second_elf[second_elf_split+1:])
    
    # How many fully contained sections are there?
    if ( (first_elf_lower >= second_elf_lower and first_elf_lower <= second_elf_upper) or
         (first_elf_upper >= second_elf_lower and first_elf_upper <= second_elf_upper) or
         (second_elf_lower >= first_elf_lower and second_elf_lower <= first_elf_upper) or
         (second_elf_upper >= first_elf_lower and second_elf_upper <= first_elf_upper) ):
        partly_contained_count += 1
    
# print('Total number of fully contained sections:', partly_contained_count)
# Out:
# 3.61 ms ± 504 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
